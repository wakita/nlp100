# %% [markdown]
# # NLP 100 第6章

# %%
import sys

# %%
sys.argv
# Out:
# ['/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py',
#  '-f',
#  '/root/.local/share/jupyter/runtime/kernel-8df3f76b-c1e1-4792-afa1-fb881ad2c197.json']

# %%
sys.displayhook?
